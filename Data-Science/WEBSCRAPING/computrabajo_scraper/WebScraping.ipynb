# %%
pip install requests beautifulsoup4 pandas openpyxl lxml
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.8 MB 5.9 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/9.8 MB 6.4 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/9.8 MB 6.5 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.8 MB 6.3 MB/s eta 0:00:01
#    ------------------------- -------------- 6.3/9.8 MB 6.4 MB/s eta 0:00:01
#    -------------------------------- ------- 7.9/9.8 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.8 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 6.4 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ------------ --------------------------- 1.3/4.1 MB 6.6 MB/s eta 0:00:01
#    ------------------------- -------------- 2.6/4.1 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.1 MB 6.4 MB/s eta 0:00:01
# ...

# %%
pip install playwright
# Out:
# ...
#    ---------------------------------------- 0.0/37.9 MB ? eta -:--:--
#     --------------------------------------- 0.8/37.9 MB 5.7 MB/s eta 0:00:07
#    -- ------------------------------------- 2.1/37.9 MB 5.9 MB/s eta 0:00:07
#    --- ------------------------------------ 3.1/37.9 MB 6.0 MB/s eta 0:00:06
#    ---- ----------------------------------- 4.5/37.9 MB 5.9 MB/s eta 0:00:06
#    ------ --------------------------------- 5.8/37.9 MB 5.8 MB/s eta 0:00:06
#    ------ --------------------------------- 6.3/37.9 MB 5.4 MB/s eta 0:00:06
#    -------- ------------------------------- 7.9/37.9 MB 5.6 MB/s eta 0:00:06
#    --------- ------------------------------ 9.2/37.9 MB 5.6 MB/s eta 0:00:06
#    ---------- ----------------------------- 10.2/37.9 MB 5.6 MB/s eta 0:00:05
#    ----------- ---------------------------- 11.3/37.9 MB 5.6 MB/s eta 0:00:05
#    ------------- -------------------------- 12.8/37.9 MB 5.7 MB/s eta 0:00:05
# ...

# %%
import os

print(os.getcwd())
# Out:
# C:\WINDOWS\system32

# %%
import os

os.chdir(r"C:\Users\Ariel\Documents\Proyectos")

print(os.getcwd())
# Out:
# C:\Users\Ariel\Documents\Proyectos

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Ariel\Documents\Proyectos
